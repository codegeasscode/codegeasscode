# %%
def compare(x,y):
    if x>int(y):
        return "your number is lower than mine"
    return "your number is greater than mine"


import random
guesses=3
Name=input("Enter your name: ")
print(f'{Name} want to play Number guessing game.')
while True:
    reply=input('[Y] for new game  or [N] for exit : ').lower()
    if reply.strip() == "y":
        tries=0
        level=input("[E] for easy or [H] for hard or [Press any letter] for main menu ").lower()
        if (level.strip() == "e") or (level.strip() == "h"):
            if level.strip() == "e":
                num=random.randint(1,11)
                print(f"Hello,I am thinking of no.between 1 and 11\n Can you guess it?\nYou have {guesses} guesses.")
                if num%2 == 0:
                    print("It is an even number.")
                else:
                    print("It is an odd number.")
            else:
                num=random.randint(1,101)
                print(f"Hello,I am thinking of no.between 1 and 101\n Can you guess it?\nYou have {guesses} guesses.")
                for i in range(3,num//2):
                    if num%i == 0:
                        print("Number is divisible by ",i)
                        break
                else:
                    print("Number is a prime number.")
            for i in range(0,guesses):
                z=True
                while z:
                    try:
                        guess=int(input("Enter your Guess: "))
                        z=False
                    except:
                        print("Enter a valid value")
            
                if guess == num:
                    print(f"Nice! You got it!\n It took you {i+1} attempts\n Would you like to play again")
                    break
                else:
                    print("Oh no!, it's not correct.")
                    hint=input(f"Hey !\n need help\n press [H] for hint or press [ any other letter] to continue").lower()
                    if hint.strip() == "h":
                        print(compare(num, guess))
                    else:
                        print("I like that confidence, carry on.")
            print("I was thinking of ",num,"\n try again!")
            
            
        else:
            break
    elif reply.strip() == "n":
        print("Thank you , have a good day!")
        break
    else:
        print("Enter a valid argument")
# Out:
# Enter your name: alok
# alok want to play Number guessing game.
# [Y] for new game  or [N] for exit : y
# [E] for easy or [H] for hard or [Press any letter] for main menu e
# Hello,I am thinking of no.between 1 and 11
#  Can you guess it?
# You have 3 guesses.
# It is an odd number.
# Enter your Guess: 5
# Hey !
#  need help
#  press [H] for hint or press [ any other letter] to continueh
# your number is greater than mine
# Enter your Guess: 7
# Hey !
#  need help
#  press [H] for hint or press [ any other letter] to continueh
# your number is greater than mine
# Enter your Guess: 3
# Nice! You got it!
#  It took you 3 attempts
#  Would you like to play again
# I was thinking of  3
#  try agin!
# [Y] for new game  or [N] for exit : n
# Thank you , have a good day!
